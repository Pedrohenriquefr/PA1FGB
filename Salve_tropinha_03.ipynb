# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedrohenriquefr/PA1FGB/blob/main/Salve_tropinha_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula do Marcinho

# %%
lado1 = 2
lado2 = 5
#cálculo da área
area = lado1 + lado2
#calculo da area de um quadrado
areaquadrado = lado1 * lado2
print (areaquadrado)
# Out:
# 10

# %%
print ("hello world!")
# Out:
# hello world!

# %%
nome = "Pedrin do capa ff"
idade = 14
altura = 1,67
print (f"nome : {nome}, Idade: {idade}, altura: {altura}")
# Out:
# nome : Pedrin do capa ff, Idade: 14, altura: (1, 67)
