# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedrohenriquefr/PA1FGB/blob/main/Salve_tropinha_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world!")
# Out:
# hello world!
